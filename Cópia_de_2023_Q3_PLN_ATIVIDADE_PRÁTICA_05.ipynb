# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizjafelice/Atividade-5-PLN/blob/master/C%C3%B3pia_de_2023_Q3_PLN_ATIVIDADE_PR%C3%81TICA_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Processamento de Linguagem Natural [2023.Q3]**
# Prof. Alexandre Donizeti Alves

# %% [markdown]
# ### **ATIVIDADE PRÁTICA 05 [LangChain + Grandes Modelos de Linguagem + API]**

# %% [markdown]
# A **ATIVIDADE PRÁTICA 05** deve ser feita utilizando o **Google Colab** com uma conta sua vinculada ao Gmail. O link do seu notebook, armazenado no Google Drive, além do link de um repositório no GitHub e os principais resultados da atividade, devem ser enviados usando o seguinte formulário:
#
# > https://forms.gle/C1oUi1FKTZ4W9fNdA
#
#
# **IMPORTANTE**: A submissão deve ser feita até o dia **10/12 (domingo)** APENAS POR UM INTEGRANTE DA EQUIPE, até às 23h59. Por favor, lembre-se de dar permissão de ACESSO IRRESTRITO para o professor da disciplina de PLN.

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# **POR FAVOR, PREENCHER OS INTEGRANDES DA SUA EQUIPE:**
#
#
# **Integrante 01:**
#
# `Por favor, informe o seu nome completo e RA:` Beatriz Fanuele Jafelice - 11202130429
#
# **Integrante 02:**
#
# `Por favor, informe o seu nome completo e RA:` Letícia Matias de Araujo - 11201810422

# %% [markdown]
# ### **GRANDE MODELO DE LINGUAGEM (*Large Language Model - LLM*)**
#
# ---

# %% [markdown]
# Cada equipe deve selecionar um Grande Modelo de Linguagem (*Large Language Model - LMM*). Preferencialmente, usar um modelo gratuito. Cada modelo pode ser escolhido por até 2 equipes.
#
# >
#
# Uma lista de LLMs está disponível em:
#
# > https://integrations.langchain.com/llms
# > https://python.langchain.com/docs/integrations/llms/

# %% [markdown]
# **Modelos da Hugging Face:**
#
# * Mistral Base: modelo promissor.
#
# > https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.1
#
# * Mistral Quantizado: mais leve. Pode ser um pouco mais difícil de configurar, mas deve ocupar menos memória.
#
# > https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.1-GGUF
#
# * Mistral Lite da Amazon: pode ter desempenho melhor.
#
# > https://huggingface.co/amazon/MistralLite
#
# * Llama 2 7B: modelo da Meta melhorado.
#
# > https://huggingface.co/meta-llama/Llama-2-7b-chat-hf
#
# * Llama 2 7b 32k: contexto maior pelo mesmo tamanho.
#
# > https://huggingface.co/togethercomputer/Llama-2-7B-32K-Instruct
#
# * Galactica: para artigos científicos
#
# > https://huggingface.co/facebook/galactica-6.7b
#
# * Alpaca: alternativo ao Llama
#
# > https://huggingface.co/chavinlo/alpaca-native
#
# > https://huggingface.co/spaces/tloen/alpaca-lora

# %% [markdown]
# **Lista de Modelos Interessantes:**
#
# > https://www.kdnuggets.com/2023/04/8-opensource-alternative-chatgpt-bard.html
#
# * Vicuna:
# > https://huggingface.co/lmsys/vicuna-7b-v1.5-16k
#
# * Openchat kit:
# > https://huggingface.co/togethercomputer/GPT-NeoXT-Chat-Base-20B
#
# * Meta OPT:
# > https://huggingface.co/facebook/opt-1.3b
#
# * Google Flan:
# > https://huggingface.co/google/flan-t5-base

# %% [markdown]
# **APIs:**
#
# * GPT4ALL: tenta ser um chatGPT aberto
# > https://python.langchain.com/docs/integrations/llms/gpt4all
#
# * YandexGPT: da empresa russa que criou um modelo de *Machine Learning* clássico muito bom, o CatBoost.
# > https://python.langchain.com/docs/integrations/llms/yandex
#
# * Anthropic: empresa forte concorrente da OpenAi.
# > https://python.langchain.com/docs/integrations/chat/anthropic
#
# * Gorilla: pipeline para geração de código
#  > https://www.kdnuggets.com/2023/06/meet-gorilla-uc-berkeley-microsoft-apiaugmented-llm-outperforms-gpt4-chatgpt-claude.html

# %% [markdown]
# **IMPORTANTE**: todo esse levantamento e comentários foram feitos pelo aluno  **Bruno Sanches Rodrigues**.

# %% [markdown]
# Por favor, informe os dados do LLM selecionada:
#
# >
#
#
# **LLM**: Galactica
#
# >
#
# **Link para a documentação oficial**: https://huggingface.co/facebook/galactica-6.7b
#
# >
#
#
# **Site oficial (GitHub)**: https://github.com/paperswithcode/galai/tree/main

# %% [markdown]
# **IMPORTANTE**: não pode ser o modelo da `OpenAI`.

# %% [markdown]
# ### **API**
# ---

# %% [markdown]
# Por favor, informe os dados da API selecionada:
#
# **API**: Telegram Bot API
#
# **Site oficial**: https://core.telegram.org/api
#
# **Link para a documentação oficial**: https://core.telegram.org/bots/api

# %% [markdown]
# **IMPORTANTE**: não é necessário usar a mesma **API** da `ATIVIDADE PRÁTICA 03`. Cada **API** pode ser usada por até 2 equipes.

# %% [markdown]
# ### **DESCRIÇÃO**
# ---

# %% [markdown]
# Implementar um `notebook` no `Google Colab` que faça uso do framework **`LangChain`** (obrigatório) e de um **LLM** aplicando, no mínimo, uma técnica de PLN. A técnica pode ser aplicada em qualquer córpus. Também é obrigatório usar uma **API** da `ATIVIDADE PRÁTICA 03`. A **API** pode ser usada tanto para obter os dados quanto para disponibilizar os resultados.
#
# O **LLM** e a **API** selecionados devem ser informados na seguinte planilha:
#
# > https://docs.google.com/spreadsheets/d/1cOL7zVNffqmliuv23zFm1UJjhEXTdp1Zm5EyAJmhiKg/edit?usp=sharing
#
# >
# As seguintes técnicas de PLN podem ser usadas:
#
# *   Correção Gramatical
# *   Classificação de Textos
# *   Análise de Sentimentos
# *   Detecção de Emoções
# *   Extração de Palavras-chave
# *   Tradução de Textos
# *   Sumarização de Textos
# *   Similaridade de Textos
# *   Reconhecimento de Entidades Nomeadas
# *   Sistemas de Perguntas e Respostas
#
# >
#
#
#
#
# **Lista de APIs:**
#
#
# * YouTube
# * LinkedIn
# * Twitter (X)
# * Facebook
# * Instagram
# * Medium
# * Reddit
# * TikTok
# * GitHub
# * Pinterest
# * Telegram
# * Dados financeiros
# * Notícias
# * Mercado de Ações
# * Dados financeiros
# * SMS
# * OpenAlex
# * Whisper (OpenAI)
# * Discord
# * Slack
# * Chuck Norris Jokes
# * Wikipedia
# * Last.fm
# * New York Times
# * Nasdaq Data Link
# * Yahoo! Finance
# * Twilio SendGrid Mail Send
# * Spotify
# * Awesome API
# * Google Books API
# * Mercado Livre API
#
# >
#
# **PLANILHA DA ATIVIDADE PRÁTICA 03:**
#
# > https://docs.google.com/spreadsheets/d/1-Q1szJ3UmoE2_3LtcRQyqid5fPIcnpsR3XAPnoxLj2o/edit?usp=sharing
#
#
# **IMPORTANTE:** É obrigatório usar o e-mail da UFABC.

# %% [markdown]
# ### **CRITÉRIOS DE AVALIAÇÃO**
# ---

# %% [markdown]
# Serão considerados como critérios de avaliação os segunintes pontos:
#
# * Uso do framework **`LangChain`**.
#
# * Escolha e uso de um **LLM**.
#
# * Escolha e uso de uma **API**
#
# * Criatividade no uso do framework **`LangChain`** em conjunto com o **LLM** e a **API**.

# %% [markdown]
# **IMPORTANTE**: todo o código do notebook deve ser executado. Código sem execução não será considerado.

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %% [markdown]
# ### Testando diferentes LLMs

# %% [markdown]
# **Observações:** <br>
# **1)** Para utilizar os modelos do HuggingFace, é necessário obter uma chave (token) para autenticação. Para obtê-la, siga os seguintes passos:
# * Criar uma conta em https://huggingface.co/welcome;
# * Clique no seu perfil e siga para "Settings";
# * Na aba "Acess Tokens", gere um novo token.

# %% [markdown]
# **2)** Os códigos foram testados utilizando o ambiente de execução T4 do Google Colab, disponível gratuitamente e ligeiramente superior ao ambiente de execução padrão:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### YandexGPT

# %%
# Importando as bibliotecas necessárias

# %%
! pip install langchain

# %%
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 4.6 MB/s eta 0:00:00
# ...

# %%
! pip install yandexcloud
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 26.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.25.1 which is incompatible.
# ...

# %%
llm = YandexGPT()
llm_chain = LLMChain(prompt=prompt, llm=llm)
country = "Russia"

llm_chain.run(country)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-12-4fd619579997> in <cell line: 1>()
# ----> 1 llm = YandexGPT()
#       2 llm_chain = LLMChain(prompt=prompt, llm=llm)
#       3 country = "Russia"
#       4
#       5 llm_chain.run(country)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/load/serializable.py in __init__(self, **kwargs)
#      95
#      96     def __init__(self, **kwargs: Any) -> None:
# ---> 97         super().__init__(**kwargs)
#      98         self._lc_kwargs = kwargs
#      99
#
# /usr/local/lib/python3.10/dist-packages/pydantic/main.cpython-310-x86_64-linux-gnu.so in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for YandexGPT
# __root__
#   Either 'YC_API_KEY' or 'YC_IAM_TOKEN' must be provided. (type=value_error)

# %% [markdown]
# Ao tentar gerar um token para o [YandexGPT](https://cloud.yandex.com/en/docs/yandexgpt/pricing), nota-se que o modelo está em Preview e segue algumas políticas de cobrança por uso, de modo semelhante à API da OpenAI:
# ![image.png](data:image/png;base64,...)
#
# Para utilizá-lo, é necessário iniciar um teste gratuito. Como o escopo da atividade é voltado para modelos gratuitos, seguiremos com outros testes.

# %% [markdown]
# #### Chat Antropic

# %%
# !pip install anthropic
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.1/808.1 kB 8.7 MB/s eta 0:00:00
# ...

# %%
from langchain.chat_models import ChatAnthropic
from langchain.schema import HumanMessage

# %% [markdown]
# Tentativa de autenticação com a chave do HuggingFace:

# %%
from getpass import getpass
chat = ChatAnthropic(anthropic_api_key=getpass())
# Out:
# ··········

# %%
messages = [
    HumanMessage(
        content="Translate this sentence from English to French. I love programming."
    )
]
chat(messages)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-14-8a528bff6f7e> in <cell line: 6>()
#       4     )
#       5 ]
# ----> 6 chat(messages)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in __call__(self, messages, stop, callbacks, **kwargs)
#     630         **kwargs: Any,
#     631     ) -> BaseMessage:
# --> 632         generation = self.generate(
#     633             [messages], stop=stop, callbacks=callbacks, **kwargs
#     634         ).generations[0][0]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     376                 if run_managers:
#     377                     run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 378                 raise e
# ...

# %% [markdown]
# Para utilizar a API do Chat Anthropic, é necessário solicitar acesso à ferramenta pelo site oficial, conforme abaixo:
# ![image.png](data:image/png;base64,...)
#
# Link para a página oficial: [Anthropic](https://docs.anthropic.com/claude/reference/getting-started-with-the-api)

# %% [markdown]
# #### Llama2-7B

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# !pip install -qqq openai
# !pip install -Uqqq chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 910.1 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.4/181.4 kB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.4/221.4 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import os
import textwrap

import langchain
import chromadb
import transformers
import openai
import torch

from transformers import AutoTokenizer
from langchain import HuggingFacePipeline
from langchain.text_splitter import CharacterTextSplitter
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# %% [markdown]
# É necessário inserir o token gerado no site do HuggingFace no prompt gerado pela célula abaixo:

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# ...

# %%
#Set up HuggingFace Pipeline with Llama-2-7b-chat-hf model
model = "meta-llama/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
      "text-generation", #task
      model=model,
      tokenizer=tokenizer,
      torch_dtype=torch.bfloat16,
      trust_remote_code=True,
      device_map="auto",
      max_length=1000,
      do_sample=True,
      top_k=10,
      num_return_sequences=1,
      eos_token_id=tokenizer.eos_token_id
)

#LLM intialized in HuggingFace Pipeline wrapper
llm = HuggingFacePipeline(pipeline = pipeline, model_kwargs = {'temperature':0})
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     269     try:
# --> 270         response.raise_for_status()
#     271     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...

# %% [markdown]
# Assim como no caso do Chat Anthropic, somente usuários autorizados podem acessar o modelo.

# %% [markdown]
# #### Amazon Mistral Lite

# %% [markdown]
# **Nota:** para melhorar o desempenho, foram aplicadas algumas alterações nas configurações padrão do parâmetro "device_map". Link para o tutorial: https://huggingface.co/blog/accelerate-large-models

# %%
from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer
import transformers
import torch
from accelerate import infer_auto_device_map, init_empty_weights

model_id = "amazon/MistralLite"

config = AutoConfig.from_pretrained(model_id)
with init_empty_weights():
    model = AutoModelForCausalLM.from_config(config)

device_map = infer_auto_device_map(model, no_split_module_classes=["OPTDecoderLayer"], dtype="float16")
device_map["model.decoder.layers.37"] = "disk"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id,
                                             offload_folder="offload",
                                             offload_state_dict = True,
                                             torch_dtype=torch.bfloat16,
                                             use_flash_attention_2=False,
                                             device_map=device_map)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
prompt = "<|prompter|>What are the main challenges to support a long context for LLM?</s><|assistant|>"

sequences = pipeline(
    prompt,
    max_new_tokens=400,
    do_sample=False,
    return_full_text=False,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"{seq['generated_text']}")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# pytorch_model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# Mesmo com as configurações adicionais, a execução foi finalizada automaticamente por insuficiência de memória RAM no ambiente do Google Colab.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Mistral 7B

# %%
# Código de teste disponível na documentação: https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.1
from transformers import AutoModelForCausalLM, AutoTokenizer

device = "cuda" # the device to load the model onto

model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.1")
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.1")

messages = [
    {"role": "user", "content": "What is your favourite condiment?"},
    {"role": "assistant", "content": "Well, I'm quite partial to a good squeeze of fresh lemon juice. It adds just the right amount of zesty flavour to whatever I'm cooking up in the kitchen!"},
    {"role": "user", "content": "Do you have mayonnaise recipes?"}
]

encodeds = tokenizer.apply_chat_template(messages, return_tensors="pt")

model_inputs = encodeds.to(device)
model.to(device)

generated_ids = model.generate(model_inputs, max_new_tokens=1000, do_sample=True)
decoded = tokenizer.batch_decode(generated_ids)
print(decoded[0])
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/5.06G [00:00<?, ?B/s]

# %% [markdown]
# Assim como no exemplo anterior, a execução foi finalizada automaticamente por insuficiência de memória RAM no ambiente do Google Colab.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Galactica

# %%
# Instalando os modelos necessários

! pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 1.9 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, OPTForCausalLM, AutoConfig, AutoModelForCausalLM
import torch
from accelerate import infer_auto_device_map, init_empty_weights

model_id = "facebook/galactica-6.7b"

config = AutoConfig.from_pretrained(model_id)
with init_empty_weights():
    model = AutoModelForCausalLM.from_config(config)

device_map = infer_auto_device_map(model, no_split_module_classes=["OPTDecoderLayer"], dtype="float16")
device_map["model.decoder.layers.37"] = "disk"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = OPTForCausalLM.from_pretrained(model_id,
                                      offload_folder="offload",
                                      offload_state_dict = True,
                                      torch_dtype=torch.bfloat16,
                                      use_flash_attention_2=False,
                                      device_map=device_map)

input_text = "The Transformer architecture [START_REF]"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# tokenizer_config.json:   0%|          | 0.00/166 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.14M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.00 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/45.1k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.96G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.77G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the disk.
# ...

# %% [markdown]
# Modelo carregado com sucesso.

# %%
# Exemplo do site oficial
input_text = "A paper proving that a simply connected, closed 3-manifold is homeomorphic to the 3-sphere"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")

outputs = model.generate(input_ids, max_length=200, num_return_sequences=1)
print(tokenizer.decode(outputs[0]))
# Out:
# A paper proving that a simply connected, closed 3-manifold is homeomorphic to the 3-sphere is called a proof of the Poincaré conjecture.
#
# ## History
#
#  The Poincaré conjecture was first stated by Henri Poincaré in 1904, but it was not until 1912 that the first proof was published by Max Dehn.[START_REF] Über unendliche diskontinuierliche Gruppen, Dehn[END_REF] Dehn's proof was based on the fact that a 3-manifold is determined by its fundamental group, and that the fundamental group of a 3-manifold is finitely presented.
#
# The Poincaré conjecture was proved for all 3-manifolds with the exception of the Poincaré homology sphere, which is the only closed, orientable, irreducible 3-manifold with the same homology as the 3-sphere. The Poincaré homology sphere was first constructed by Heinz Hopf in 1931.[START_REF] Über die Abbildungen

# %% [markdown]
# Devido ao sucesso obtido nos testes, o LLM escolhido para essa atividade é o [Galactica](https://huggingface.co/facebook/galactica-6.7b), um modelo treinado especificamente em materiais de cunho acadêmico (artigos, enciclopédias, notas de palestras, etc).

# %% [markdown]
# ## Integração com a API do Telegram

# %% [markdown]
# Prosseguindo para a segunda parte da atividade, uniremos as funcionalidades do LLM Galactica com a API do Telegram, utilizada na Atividade 3. O objetivo é configurar um chatbot em que o usuário possa consultar artigos científicos relacionados a um determinado tema de interesse, que deve ser especificado no prompt. Essa integração envolve as seguintes técnicas de PLN:
# * **Extração de Palavras-Chave:** ao receber o prompt do usuário, o LLM deve capturar as palavras-chave relacionadas ao tema de interesse;
# * **Similaridade de Textos:** ao buscar artigos relacionados ao tema de interesse do usuário, o LLM deverá buscar córpus em que essas palavras-chave estão presente, ou seja, que possuem semelhança com o input do usuário.

# %% [markdown]
# **IMPORTANTE: Limitações** <br>
# Essa atividade é apenas uma demonstração do que poderia ser feito com um modelo de linguagem com os mesmos objetivos do Galactica. **Não recomendamos** o uso desse modelo para obter citações de artigos científicos e sugerimos que **todas as informações obtidas pelo modelo sejam verificadas**. Segundo esse [artigo](https://www.technologyreview.com/2022/11/18/1063487/meta-large-language-model-ai-only-survived-three-days-gpt-3-science/) da MIT Technology Review, o modelo foi descontinuado pela própria Meta em razão da frequência de alunicações e informações falsas em suas respostas. Com efeito, o [notebook demonstrativo](https://github.com/paperswithcode/galai/blob/main/notebooks/Introduction%20to%20Galactica%20Models.ipynb) disponibilizado pelos desenvolvedores alerta para algumas limitações desse modelo.

# %% [markdown]
# ### Utilizando um bot já criado do Telegram

# %% [markdown]
# #### Instalando as bibliotecas necessárias

# %% [markdown]
# Precisamos verificar qual é o encoding correto, porque depois de instalar e configurar o Galactica, apareceu que o código local é ANSI_X3.4-1968.

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %% [markdown]
# Vamos mudar para UTF-8.

# %%
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %% [markdown]
# Instalando as bibliotecas necessárias para o bot do Telegram

# %%
! pip install responses
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 811.7 kB/s eta 0:00:00
# ...

# %%
# !pip install nest_asyncio

# %%
# Instalação do pacote python-telegram-bot:
! pip install python-telegram-bot
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 552.6/552.6 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# Bibliotecas necessárias para a utilização

from typing import Final
from telegram import Update
from telegram.ext import *
import logging
import responses
import nest_asyncio
from getpass import getpass

# %%
# Primeiro, coloque o token dado pelo BotFather
TOKEN = getpass()
# Out:
# ··········

# %%
# Criando o logging

logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', level=logging.INFO)
logging.info('Inicializando o bot...')

async def start_command(update: Update, context: ContextTypes.DEFAULT_TYPE):
  await update.message.reply_text('Olá! Sou um robô!')

async def help_command(update: Update, context: ContextTypes.DEFAULT_TYPE):
  await update.message.reply_text('Em que posso te ajudar?')

async def custom_command(update: Update, context: ContextTypes.DEFAULT_TYPE):
  await update.message.reply_text('Esse é um comando personalizado.')

async def handle_message(update: Update, context: ContextTypes.DEFAULT_TYPE):
  text = update.message.text
  input_ids = tokenizer(text, return_tensors="pt").input_ids.to("cuda")
  outputs = model.generate(input_ids, max_length=200, num_return_sequences=1)
  final_text = tokenizer.decode(outputs[0])
  y = final_text.split('\n')
  if len(y) > 0:
    final = y[0]
  else:
    x = final_text.split(". ")
    final = final_text.replace(x[-2], '')
    final = final.replace(". . . . . . ", '')
    final = final.replace(x[-1], '')

    final = final + " " + x[-2] + "."

  await update.message.reply_text(final)


async def error(update, context):
  logging.error(f'Update ({update}) caused error: {context.error}')

def main():

  # Cria uma aplicação com o token a ser utilizado

  application = Application.builder().token(TOKEN).build()


  # Comandos

  application.add_handler(CommandHandler('start', start_command))
  application.add_handler(CommandHandler('help', help_command))
  application.add_handler(CommandHandler('custom', custom_command))

  # Mensagens

  application.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, handle_message))

  # Rodando o bot

  # Precisamos utilizar o nest_asyncio para poder rodar o bot no Google Colab

  nest_asyncio.apply()

  application.run_polling(allowed_updates=Update.ALL_TYPES)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-7b6ab5e1f38e> in <cell line: 62>()
#      61
#      62 if __name__ == "__main__":
# ---> 63     main()
#
# <ipython-input-19-7b6ab5e1f38e> in main()
#      58   nest_asyncio.apply()
#      59
# ---> 60   application.run_polling(allowed_updates=Update.ALL_TYPES)
#      61
#      62 if __name__ == "__main__":
#
# /usr/local/lib/python3.10/dist-packages/telegram/ext/_application.py in run_polling(self, poll_interval, timeout, bootstrap_retries, read_timeout, write_timeout, connect_timeout, pool_timeout, allowed_updates, drop_pending_updates, close_loop, stop_signals)
#     816             self.create_task(self.process_error(error=exc, update=None))
#     817
# --> 818         return self.__run(
#     819             updater_coroutine=self.updater.start_polling(
#     820                 poll_interval=poll_interval,
# ...

# %% [markdown]
# O erro de "Cannot close a runnig event loop" aparece quando terminamos de executar o código acima, mas o bot do Telegram funciona corretamente.

# %% [markdown]
# #### Exemplos de como o programa funciona

# %% [markdown]
# **Nota:** os exemplos foram feitos em inglês, pois a biblioteca funciona melhor nesse idioma.

# %% [markdown]
# ##### Primeiro exemplo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### Segundo exemplo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### Terceiro exemplo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### Quarto exemplo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Conclusão

# %% [markdown]
# Percebe-se que o Galactica tem algumas limitações. Porém, em geral, o programa desenvolvido funciona bem quando se pede um artigo ou livro mais específico. Contudo, quando se pede algo mais geral, o modelo se restringe a poucas informações - como no exemplo 2, com o input "a paper about life", em que o Galactica resumiu brevemente o livro de exemplo.
